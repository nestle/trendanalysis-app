# %% [markdown]
# Import libraries

# %%
import os
import json
from pix2text import Pix2Text
import re
import numpy as np
import pandas as pd
from io import StringIO
from openpyxl.utils import get_column_letter
from openpyxl import load_workbook

# %% [markdown]
# Use Pix2Text

# %%
pdf_path = '/nihs/NR/DSS/Project/WONI_DUND_102208/WONI_Zied/project/investigation_codes/ff_ffn_monthly-report_202406.pdf'

p2t = Pix2Text.from_config()

document = p2t.recognize_pdf(pdf_path)

output_dir = 'output_markdown'
os.makedirs(output_dir, exist_ok=True)
document.to_markdown(output_dir)
# Out:
# Fix size testing.
# training chunk_sizes: [32]
# The output will be saved to  /gpfs/home/rdmustapzi/miniconda3/envs/env/lib/python3.10/site-packages/pix2text/doc_xl_layout/../../exp/ctdet_subfield/default
# heads {'hm': 11, 'cls': 4, 'ftype': 3, 'wh': 8, 'hm_sub': 2, 'wh_sub': 8, 'reg': 2, 'reg_sub': 2}
# Loading /gpfs/home/rdmustapzi/.pix2text/1.1/mfd-onnx/mfd-v20240618.onnx for ONNX Runtime inference...
#
# WARNING ⚠️ imgsz=[1085, 768] must be multiple of max stride 32, updating to [1088, 768]
# 0: 1088x768 (no detections), 128.0ms
# Speed: 6.2ms preprocess, 128.0ms inference, 0.7ms postprocess per image at shape (1, 3, 1088, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[248, 1728] must be multiple of max stride 32, updating to [256, 1728]
# 0: 256x1728 2 embeddings, 62.2ms
# Speed: 3.3ms preprocess, 62.2ms inference, 1.7ms postprocess per image at shape (1, 3, 256, 1728)
# 100%|██████████| 2/2 [00:00<00:00,  6.07it/s]
# WARNING ⚠️ imgsz=[159, 1728] must be multiple of max stride 32, updating to [160, 1728]
# 0: 160x1728 (no detections), 45.0ms
# Speed: 2.1ms preprocess, 45.0ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 1728)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[261, 1728] must be multiple of max stride 32, updating to [288, 1728]
# 0: 288x1728 4 embeddings, 68.3ms
# Speed: 3.1ms preprocess, 68.3ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 1728)
# 100%|██████████| 4/4 [00:00<00:00,  5.04it/s]
# WARNING ⚠️ imgsz=[253, 1728] must be multiple of max stride 32, updating to [256, 1728]
# 0: 256x1728 1 embedding, 63.8ms
# Speed: 2.8ms preprocess, 63.8ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 1728)
# 100%|██████████| 1/1 [00:00<00:00,  4.59it/s]
# WARNING ⚠️ imgsz=[113, 1728] must be multiple of max stride 32, updating to [128, 1728]
# 0: 128x1728 (no detections), 75.3ms
# Speed: 1.7ms preprocess, 75.3ms inference, 0.5ms postprocess per image at shape (1, 3, 128, 1728)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[149, 768] must be multiple of max stride 32, updating to [160, 768]
# 0: 160x768 1 isolated, 36.5ms
# Speed: 1.7ms preprocess, 36.5ms inference, 0.8ms postprocess per image at shape (1, 3, 160, 768)
# 100%|██████████| 1/1 [00:00<00:00,  2.80it/s]
# WARNING ⚠️ imgsz=[98, 1152] must be multiple of max stride 32, updating to [128, 1152]
# 0: 128x1152 (no detections), 88.6ms
# Speed: 10.6ms preprocess, 88.6ms inference, 0.5ms postprocess per image at shape (1, 3, 128, 1152)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[100, 768] must be multiple of max stride 32, updating to [128, 768]
# 0: 128x768 (no detections), 56.6ms
# Speed: 0.9ms preprocess, 56.6ms inference, 0.5ms postprocess per image at shape (1, 3, 128, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[156, 1728] must be multiple of max stride 32, updating to [160, 1728]
# 0: 160x1728 (no detections), 46.2ms
# Speed: 1.9ms preprocess, 46.2ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 1728)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[153, 1728] must be multiple of max stride 32, updating to [160, 1728]
# 0: 160x1728 (no detections), 47.5ms
# Speed: 2.4ms preprocess, 47.5ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 1728)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[356, 1728] must be multiple of max stride 32, updating to [384, 1728]
# 0: 384x1728 6 embeddings, 106.7ms
# Speed: 4.2ms preprocess, 106.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 1728)
# 100%|██████████| 5/5 [00:01<00:00,  4.94it/s]
# WARNING ⚠️ imgsz=[218, 1728] must be multiple of max stride 32, updating to [224, 1728]
# 0: 224x1728 (no detections), 142.5ms
# Speed: 3.2ms preprocess, 142.5ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 1728)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[993, 768] must be multiple of max stride 32, updating to [1024, 768]
# 0: 1024x768 (no detections), 155.6ms
# Speed: 7.8ms preprocess, 155.6ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[104, 768] must be multiple of max stride 32, updating to [128, 768]
# 0: 128x768 (no detections), 85.0ms
# Speed: 1.0ms preprocess, 85.0ms inference, 2.2ms postprocess per image at shape (1, 3, 128, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[993, 768] must be multiple of max stride 32, updating to [1024, 768]
# 0: 1024x768 2 embeddings, 116.0ms
# Speed: 6.8ms preprocess, 116.0ms inference, 1.1ms postprocess per image at shape (1, 3, 1024, 768)
# 100%|██████████| 2/2 [00:00<00:00,  6.29it/s]
# WARNING ⚠️ imgsz=[993, 768] must be multiple of max stride 32, updating to [1024, 768]
# 0: 1024x768 (no detections), 104.1ms
# Speed: 6.5ms preprocess, 104.1ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[993, 768] must be multiple of max stride 32, updating to [1024, 768]
# 0: 1024x768 (no detections), 109.8ms
# Speed: 6.2ms preprocess, 109.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[993, 768] must be multiple of max stride 32, updating to [1024, 768]
# 0: 1024x768 (no detections), 164.6ms
# Speed: 9.4ms preprocess, 164.6ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[993, 768] must be multiple of max stride 32, updating to [1024, 768]
# 0: 1024x768 (no detections), 105.0ms
# Speed: 6.7ms preprocess, 105.0ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[993, 768] must be multiple of max stride 32, updating to [1024, 768]
# 0: 1024x768 (no detections), 103.8ms
# Speed: 6.7ms preprocess, 103.8ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[993, 768] must be multiple of max stride 32, updating to [1024, 768]
# 0: 1024x768 (no detections), 112.2ms
# Speed: 6.2ms preprocess, 112.2ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[993, 768] must be multiple of max stride 32, updating to [1024, 768]
# 0: 1024x768 (no detections), 107.8ms
# Speed: 6.0ms preprocess, 107.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[993, 768] must be multiple of max stride 32, updating to [1024, 768]
# 0: 1024x768 (no detections), 113.6ms
# Speed: 6.4ms preprocess, 113.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[993, 768] must be multiple of max stride 32, updating to [1024, 768]
# 0: 1024x768 (no detections), 122.3ms
# Speed: 6.5ms preprocess, 122.3ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[99, 768] must be multiple of max stride 32, updating to [128, 768]
# 0: 128x768 (no detections), 38.0ms
# Speed: 0.9ms preprocess, 38.0ms inference, 3.8ms postprocess per image at shape (1, 3, 128, 768)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[211, 1728] must be multiple of max stride 32, updating to [224, 1728]
# 0: 224x1728 (no detections), 63.3ms
# Speed: 3.6ms preprocess, 63.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 1728)
# 0it [00:00, ?it/s]
# WARNING ⚠️ imgsz=[164, 1728] must be multiple of max stride 32, updating to [192, 1728]
# 0: 192x1728 2 embeddings, 72.9ms
# Speed: 2.2ms preprocess, 72.9ms inference, 1.1ms postprocess per image at shape (1, 3, 192, 1728)
# 100%|██████████| 2/2 [00:00<00:00,  4.84it/s]
# WARNING ⚠️ imgsz=[993, 768] must be multiple of max stride 32, updating to [1024, 768]
# 0: 1024x768 (no detections), 105.2ms
# Speed: 6.1ms preprocess, 105.2ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 768)
# 0it [00:00, ?it/s]
# '## JUNE 2024 REPORT ON EU AGRI-FOOD FRAUD SUSPICIONS\n\n![](figures/0-1-FIGURE.jpg)\n\nEuropean Commission ## The purpose of the Monthly report on EU Agri-Food Fraud suspicions is twofold:\n\nAssist Member States\' authorities for the enforcement of the provisions of Article $9 ( 2 )$ of the Official Control Regulation which requires the organisation of risk-based controls to identify and combat fraudulent and deceptive practices along the agri-food chain (across some control areas listed in its Article ${\\bf1} ( 2 ) )$ \n\n2. Provide valuable but selected information to stakeholders of the agri-food sector to perform adequate vulnerability assessments and identify new emerging risks.\n\nDisclaimer: The monthly report incudes non-compliances with fraud suspicions\' $o f$ cross-border nature identified and shared between members of the Alert and Cooperation Network $( A C N )$ and retrieved from its three components: the Rapid Alert System for Food and Feed network $( R A S F F ),$ the Administrative Assistance and Cooperation network (AAC) and the Agri-Food Fraud Network $( F F N ).$ \n\nThe monthly report covers fooo, feedingstuff materials and articles intended to come into contact dlirectly or indlirectly with food, animal welfare issues for farmed animals, plant protection products, veterinary medlicinal products andl other inouts that may end in the form of residues and contaminants $\\dot{\\imath} n$ food and feed.\n\nThe monthly report does not reconcile data and suspicions related to the following subjects:\n\n$$\n\\bullet\\, \\, \\, a n i m a l \\, a n d \\, p l a n t \\, h e a l t h,\n$$\n\nrelease into the environment of Genetically Moiied organisms,\n\nanimal welfare for companion animals,\n\nplacing on the market and use of plant protection products, veterinary medicinal prodlucts and other inputs that are not ending as residues and contaminants in food and feed, and\n\nanimal by-oroducts and derived products when they not intendedl to be useo for oral feeding to animals.\n\nCommission Implementing Regulation (EU) 2019/1715 of 30 September 2019 laying down rules for the functioning of the information management system for official controls andl its system components (the IMSOC Reculation) defines $a$ fraud notification as $a^{\\prime\\prime}$ non-compliance concerning any suspected intentional action by businesses or individuals, for the purpose of deceiving purchasers and gaining undue advantage therefrom, $i n$ violation of the rules referred to in Article ${\\bf1} ( 2 )$ of Regulation $( E U )$ 2017/625".\n\nThe report includes \'non-compliances with fraud suspicions\'. Those \'non-compliances\' are not confirmed frauds but contribute alerting and triggering investigations by Member States competent authorities.\n\n## Figure 1: Suspicions per product category\n\nAnimal by-products\nFeed additives·1\nPlant protection products n1\nPrepared dishes and snacks n 1\nWine\nCephalopods and products thereof\nCrustaceans and products thereof\nFood contact materials n 2\nHoney and royal jellyn2\nCompound Feeds m 3\nlces and desserts mm 3\nMilk and milk products m 3\nPoultry meat and poultry meat products mm 3\nAlcoholic beverages mm 4\nNuts, nut products and seeds\nFeed materials\nLive animals mm 5\nNon-alcoholic beverages\nOther food product / mixed\nConfectionery\nFats and oils\nSoups, broths, sauces and condiments\nMeat and meat products (other than poultry)\nCocoa and cocoa preparations, coffee and tea\nFish and fish products\nCereals and bakery products\nHerbs and spices\nDietetic foods, food supplements, fortified foods\nFruits and vegetables\n\nFigure 2: Suspicions per fraud category\n\nOthr non-ompliances related to plant protection products\nOther non-compliances related to animal welfare 2\nRecord tampering\nProduct tampering\nOther non-compliances (implicit claim violations)\n\n![](figures/2-2-FIGURE.jpg)\n\n| CLASSIFICATION | PRODUCT CATEGORY | COMMODITY | ISSUE | ORIGIN | NOTIFIED BY |\n| --- | --- | --- |  ...

# %% [markdown]
# Processing functions

# %%
def clean_markdown_table(raw_markdown):
    # Split the raw markdown by lines
    lines = raw_markdown.strip().split('\n')

    # Process the lines to split the columns
    table = [line.split('|')[1:-1] for line in lines]

    # Remove leading and trailing whitespaces from each cell
    table = [[cell.strip() for cell in row] for row in table]

    # Create a DataFrame
    df = pd.DataFrame(table[2:], columns=table[0])

    # Fill missing values in columns downwards
    for column in df.columns:
        df[column] = df[column].replace('', np.nan).ffill()

    return df.to_markdown(index=False)

def prepro(mdata):
    # Read the data into a DataFrame
    df = pd.read_csv(StringIO(mdata), sep="|", engine='python', on_bad_lines='warn')

    # Remove leading and trailing whitespace from column names
    df.columns = df.columns.str.strip()

    # Remove leading and trailing whitespace from each cell
    df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

    # Remove leading and trailing empty columns
    df = df.iloc[:, 1:-1]

    # Fill empty cells in the first column with the next non-empty cell
    for i in range(len(df) - 2, -1, -1):  # Start from second last row to the top
        if pd.isna(df.iloc[i, 0]) or df.iloc[i, 0] == '':
            df.iloc[i, 0] = df.iloc[i + 1, 0]

    # Replace NA with empty string for markdown conversion
    df = df.fillna('')

    # Output the corrected table
    corrected_markdown = df.to_markdown(index=False)
    return corrected_markdown

def prepro_2(mdata):
    # Read the data into a DataFrame
    df = pd.read_csv(StringIO(mdata), sep="|", engine='python')

    # Remove leading and trailing whitespace from column names
    df.columns = df.columns.str.strip()

    # Remove leading and trailing whitespace from each cell
    df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

    # Remove leading and trailing empty columns
    df = df.iloc[:, 1:-1]

    # Function to shift row elements to the right based on leading empty cells
    def shift_row(row):
        empty_count = (row == '').sum()
        if empty_count > 0:
            new_row = [''] * empty_count + row.dropna().tolist()
            return new_row[:len(row)]
        return row

    shifted_df = df.apply(shift_row, axis=1, result_type='expand')

    # Replace NA with empty string for markdown conversion
    shifted_df = shifted_df.fillna('')

    # Output the corrected table
    corrected_markdown = shifted_df.to_markdown(index=False)
    return corrected_markdown

# %%
summary_output_dir = 'summarized_output'
tables_output_dir = 'tables_output'

os.makedirs(summary_output_dir, exist_ok=True)
os.makedirs(tables_output_dir, exist_ok=True)

markdown_content = ""
tables_markdown = ""
for i, page in enumerate(document.pages):
    for j, element in enumerate(page.elements):
        element_type = str(element.type)
        if element_type == 'TEXT' or element_type == 'TITLE':
            markdown_content += element.text
        elif element_type == 'TABLE':
            table = clean_markdown_table(prepro_2(prepro(element.text)))
            #table = prepro(element.text)
            tables_markdown += table + " \n \n -------------------------------------------- \n \n"

tables_file_path = os.path.join(tables_output_dir, 'tables_markdown.md')
with open(tables_file_path, 'w') as file:
    file.write(tables_markdown)
# Out:
# [WARNING 2024-08-13 15:08:42,678 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:28: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#
# [WARNING 2024-08-13 15:08:42,686 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:53: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#
# [WARNING 2024-08-13 15:08:42,706 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:28: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#
# [WARNING 2024-08-13 15:08:42,711 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:53: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#
# [WARNING 2024-08-13 15:08:42,726 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:28: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#
# [WARNING 2024-08-13 15:08:42,730 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:53: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#
# [WARNING 2024-08-13 15:08:42,740 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:28: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#
# [WARNING 2024-08-13 15:08:42,745 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:53: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#
# [WARNING 2024-08-13 15:08:42,757 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:28: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#
# [WARNING 2024-08-13 15:08:42,762 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:53: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#
# [WARNING 2024-08-13 15:08:42,772 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:28: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#
# [WARNING 2024-08-13 15:08:42,781 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:53: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#
# [WARNING 2024-08-13 15:08:42,805 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:28: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#
# [WARNING 2024-08-13 15:08:42,813 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:53: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#
# [WARNING 2024-08-13 15:08:42,836 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:28: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#
# [WARNING 2024-08-13 15:08:42,844 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:53: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#
# [WARNING 2024-08-13 15:08:42,864 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:28: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#
# [WARNING 2024-08-13 15:08:42,873 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:53: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#
# [WARNING 2024-08-13 15:08:42,898 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:28: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#
# [WARNING 2024-08-13 15:08:42,907 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:53: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#
# [WARNING 2024-08-13 15:08:42,932 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:28: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#
# [WARNING 2024-08-13 15:08:42,941 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:53: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#
# [WARNING 2024-08-13 15:08:42,965 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:28: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#
# [WARNING 2024-08-13 15:08:42,970 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:53: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#
# [WARNING 2024-08-13 15:08:42,980 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:28: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#
# [WARNING 2024-08-13 15:08:42,984 _showwarnmsg:109] /tmp/ipykernel_332823/3651537851.py:53: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %% [markdown]
# From Markdown to Excel file

# %%
def markdown_table_to_excel(md_file_path, excel_file_path):
    with open(md_file_path, 'r') as file:
        content = file.read()

    tables = re.findall(r'\|(?:.*?\|)+', content, re.DOTALL)
    
    # Process each table
    for i, table in enumerate(tables):
        rows = table.split('\n')
        
        columns = [col.strip() for col in rows[0].split('|') if col.strip()]

        data = []
        for row in rows[2:]:
            if row.strip():
                data.append([cell.strip() for cell in row.split('|') if cell.strip()])

        df = pd.DataFrame(data, columns=columns)
        
        # Write to Excel file
        with pd.ExcelWriter(excel_file_path, engine='openpyxl', mode='a' if i > 0 else 'w') as writer:
            df.to_excel(writer, sheet_name=f'Table_{i+1}', index=False)

    # Load the workbook to adjust column widths
    wb = load_workbook(excel_file_path)
    for sheet in wb.sheetnames:
        ws = wb[sheet]
        for col in ws.columns:
            max_length = 0
            column = col[0].column_letter  # Get the column name
            for cell in col:
                try:
                    if len(str(cell.value)) > max_length:
                        max_length = len(cell.value)
                except:
                    pass
            adjusted_width = (max_length + 2)
            ws.column_dimensions[column].width = adjusted_width
    wb.save(excel_file_path)


markdown_table_to_excel('/nihs/NR/DSS/Project/WONI_DUND_102208/WONI_Zied/project/investigation_codes/tables_output/tables_markdown.md', 'output.xlsx')
